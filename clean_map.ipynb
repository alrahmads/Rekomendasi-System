# %% [markdown]
# ### 1. Load dataset LinkedIn

# %%
import pandas as pd
import json
import re
import folium
from folium.plugins import MarkerCluster

dataset = pd.read_csv("Data/LinkedIn_Job_Search.csv")
dataset = dataset.drop(columns=["Unnamed: 15", "Unnamed: 16"], errors='ignore')
dataset.head()
# Out:
#                                            Job Title      Company Name  \
# 0                  Python Machine Learning Developer        Demandlane
# 1                  Python Machine Learning Developer        Demandlane
# 2  Computer Aided Design Engineer (U.S.-Based Cli...  Eterna Indonesia
# 3  Software Engineer Full-time (AI, Video and Aud...           Videfly
# 4  Artificial Intelligence Engineer, 2 Hour Learn...         Crossover
#
#         Location                                                URL  \
# 0  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
# 1  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
# 2  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
# 3  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
# 4  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
#
#                  Company Location            company size  \
# 0                       Indonesia         11-50 employees
# 1                       Indonesia         11-50 employees
# 2                       Indonesia        51-200 employees
# 3              Jakarta, Indonesia          2-10 employees
# 4  Surabaya, East Java, Indonesia  5,001-10,000 employees
#
#                                       Industry_stats  \
# 0   Legal Services  11-50 employees   25 on LinkedIn
# 1   Legal Services  11-50 employees   25 on LinkedIn
# 2  Outsourcing and Offshoring Consulting  51-200 ...
# 3  Software Development  2-10 employees   7 on Li...
# 4  IT Services and IT Consulting  5,001-10,000 em...
#
#                                   Job Qualifications  \
# 0  AWS Lambda, Amazon Redshift, Amazon Web Servic...
# 1  AWS Lambda, Amazon Redshift, Amazon Web Servic...
# 2  3D Modeling, AutoCAD, Computer-Aided Design (C...
# 3  Amazon Web Services (AWS), Back-End Web Develo...
# 4  Angular, Artificial Intelligence (AI), Back-En...
#
#                             Job Skills  \
# 0             1 school alum works here
# 1             1 school alum works here
# 2   Skills: SketchUp, AutoCAD, +6 more
# 3  Skills: TypeScript, OpenGL, +8 more
# 4       Skills: Svelte, Flask, +8 more
#
#                                         Job Skills.1  \
# 0  5+ years of work experience with Machine Learning
# 1  5+ years of work experience with Machine Learning
# 2  3D Modeling, AutoCAD, Computer-Aided Design (C...
# 3        1+ years of work experience with JavaScript
# 4  Angular, Artificial Intelligence (AI), Back-En...
#
#                                      Job Skills.2           Profile  \
# 0  Skills: Pandas (Software), TensorFlow, +8 more        Demandlane
# 1  Skills: Pandas (Software), TensorFlow, +8 more        Demandlane
# 2                            Try Premium for IDR0  Eterna Indonesia
# 3                            Try Premium for IDR0           Videfly
# 4                            Try Premium for IDR0         Crossover
#
#                                               Skills      Type Work Hours
# 0  5+ years of work experience with Machine Learning    Remote  Full-time
# 1  5+ years of work experience with Machine Learning    Remote  Full-time
# 2  3D Modeling, AutoCAD, Computer-Aided Design (C...    Remote  Full-time
# 3        1+ years of work experience with JavaScript    Remote  Full-time
# 4  Angular, Artificial Intelligence (AI), Back-En...  Remote    Full-time

# %%
# ========================
# 2. Simplifikasi Lokasi Perusahaan
# ========================
kota_list = ['Jakarta', 'Surabaya', 'Bandung', 'Cikarang', 'Denpasar', 'Batang', 'Yogyakarta', 'Malang',
             'Pontianak', 'Kendal', 'Muarajawa', 'Tangerang', 'Pekanbaru', 'Medan', 'Lampung', 'Kuta',
             'Ubud', 'Bali', 'Bekasi', "East Java"]

def ganti_kota(lokasi):
    if isinstance(lokasi, str):
        for kota in kota_list:
            if kota in lokasi:
                return kota
    return lokasi

df = dataset.copy()
df['Company Location'] = df['Company Location'].apply(ganti_kota)
df['Company Location'] = df["Company Location"].replace({
    "East Java": "Jawa Timur", 
    "Lampung": "Bandar Lampung"
})

# %%
# ========================
# 3. Load Data Koordinat Kota
# ========================
with open("Data/location.json", 'r') as f:
    location_data = json.load(f)
location_df = pd.DataFrame(location_data)

# %%
# ========================
# 4. Merge Dataframe dengan Koordinat Kota
# ========================
df_jobs = df.merge(location_df, left_on='Company Location', right_on='Kota', how='left')
df_jobs = df_jobs.dropna(subset=["Kota"])  # Buang baris yang tidak match

# %%
# ========================
# 5. Ekstrak Koordinat dari Georeferenced
# ========================
def extract_coords(geo_str):
    try:
        lng, lat = geo_str.replace("POINT (", "").replace(")", "").split()
        return float(lng), float(lat)
    except:
        return None, None

df_jobs[['Longitude', 'Latitude']] = df_jobs['Georeferenced'].apply(
    lambda x: pd.Series(extract_coords(x))
)
df_jobs = df_jobs.dropna(subset=["Longitude", "Latitude"])
df_jobs.head()
# Out:
#                                            Job Title      Company Name  \
# 0                  Python Machine Learning Developer        Demandlane
# 1                  Python Machine Learning Developer        Demandlane
# 2  Computer Aided Design Engineer (U.S.-Based Cli...  Eterna Indonesia
# 3  Software Engineer Full-time (AI, Video and Aud...           Videfly
# 4  Artificial Intelligence Engineer, 2 Hour Learn...         Crossover
#
#         Location                                                URL  \
# 0  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
# 1  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
# 2  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
# 3  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
# 4  13 applicants  https://www.linkedin.com/jobs/search/?currentJ...
#
#   Company Location            company size  \
# 0        Indonesia         11-50 employees
# 1        Indonesia         11-50 employees
# 2        Indonesia        51-200 employees
# 3          Jakarta          2-10 employees
# 4         Surabaya  5,001-10,000 employees
#
#                                       Industry_stats  \
# 0   Legal Services  11-50 employees   25 on LinkedIn
# 1   Legal Services  11-50 employees   25 on LinkedIn
# 2  Outsourcing and Offshoring Consulting  51-200 ...
# 3  Software Development  2-10 employees   7 on Li...
# 4  IT Services and IT Consulting  5,001-10,000 em...
#
#                                   Job Qualifications  \
# 0  AWS Lambda, Amazon Redshift, Amazon Web Servic...
# 1  AWS Lambda, Amazon Redshift, Amazon Web Servic...
# 2  3D Modeling, AutoCAD, Computer-Aided Design (C...
# 3  Amazon Web Services (AWS), Back-End Web Develo...
# 4  Angular, Artificial Intelligence (AI), Back-En...
#
#                             Job Skills  \
# 0             1 school alum works here
# 1             1 school alum works here
# 2   Skills: SketchUp, AutoCAD, +6 more
# 3  Skills: TypeScript, OpenGL, +8 more
# 4       Skills: Svelte, Flask, +8 more
#
#                                         Job Skills.1  \
# 0  5+ years of work experience with Machine Learning
# 1  5+ years of work experience with Machine Learning
# 2  3D Modeling, AutoCAD, Computer-Aided Design (C...
# 3        1+ years of work experience with JavaScript
# 4  Angular, Artificial Intelligence (AI), Back-En...
#
#                                      Job Skills.2           Profile  \
# 0  Skills: Pandas (Software), TensorFlow, +8 more        Demandlane
# 1  Skills: Pandas (Software), TensorFlow, +8 more        Demandlane
# 2                            Try Premium for IDR0  Eterna Indonesia
# 3                            Try Premium for IDR0           Videfly
# 4                            Try Premium for IDR0         Crossover
#
#                                               Skills      Type Work Hours  \
# 0  5+ years of work experience with Machine Learning    Remote  Full-time
# 1  5+ years of work experience with Machine Learning    Remote  Full-time
# 2  3D Modeling, AutoCAD, Computer-Aided Design (C...    Remote  Full-time
# 3        1+ years of work experience with JavaScript    Remote  Full-time
# 4  Angular, Artificial Intelligence (AI), Back-En...  Remote    Full-time
#
#         Kota                                  Georeferenced   Longitude  \
# 0  Indonesia                   POINT (117.343188 -0.878596)  117.343188
# 1  Indonesia                   POINT (117.343188 -0.878596)  117.343188
# 2  Indonesia                   POINT (117.343188 -0.878596)  117.343188
# 3    Jakarta  POINT (106.84634081531794 -6.196639809431919)  106.846341
# 4   Surabaya                   POINT (112.740515 -7.244582)  112.740515
#
#    Latitude
# 0 -0.878596
# 1 -0.878596
# 2 -0.878596
# 3 -6.196640
# 4 -7.244582

# %%
# ========================
# 6. Bersihkan Job Title
# ========================
def extract_job_title(title):
    title = re.sub(r'\(.*?\)', '', str(title)).strip()
    title = title.split(',')[0]
    title = re.sub(
        r'\b(Senior|Junior|Lead|Head|Manager|Specialist|Full-time|Consultant|Developer|Instructor|Lecturer|GoTo Financial|Gojek|dyeing|in|MarTech|Indonesia|Intern|Experimentation)\b',
        '', title, flags=re.IGNORECASE
    ).strip()
    title = title.replace('-', '').strip()
    return title

df_jobs['Job Title'] = df_jobs['Job Title'].apply(extract_job_title)

# %%
# ========================
# 7. Filter Data-Related Jobs
# ========================
keywords = ['Data', 'Analyst', 'Analys', 'Analis', 'Analisa', 'Analisis', 
            'Analitik', 'Sains', 'Science', 'Scientist', 'Sciences', 
            'Engineer', 'Machine', 'Learning', 'Mesin', 'AI', 'Artificial', 'Intelligence']
pattern = '|'.join(keywords)

df_jobs = df_jobs[df_jobs['Job Title'].str.contains(pattern, flags=re.IGNORECASE, na=False)].reset_index(drop=True)

# %%
# ========================
# 8. Pilih Kolom yang Ingin Ditampilkan
# ========================
df_jobs = df_jobs[['Job Title', 'Company Name', 'Job Qualifications', 'URL', 'Type', 'Work Hours', 'Kota', 'Georeferenced', 'Longitude', 'Latitude']]

# Standarisasi nilai teks
df_jobs["Type"] = df_jobs["Type"].astype(str).str.strip().str.title()
df_jobs["Work Hours"] = df_jobs["Work Hours"].astype(str).str.strip().str.title()

# ========================
# 9. Simpan ke File CSV (Opsional)
# ========================
df_jobs.to_csv("Data_Clean.csv", index=False)

# %%
# ========================
# 10. Tampilkan Peta dengan Marker Cluster
# ========================
map_indonesia = folium.Map(location=[-0.789275, 113.921327], zoom_start=5)
marker_cluster = MarkerCluster().add_to(map_indonesia)

for _, row in df_jobs.iterrows():
    popup_html = f"""
        <b>{row['Job Title']}</b><br>
        Kota: {row['Kota']}<br>
        Type: {row['Type']}<br>
        Work Hours: {row['Work Hours']}<br>
        <a href="{row['URL']}" target="_blank">Link Lowongan</a>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(popup_html, max_width=300),
        tooltip=f"Lowongan di {row['Kota']}",
        icon=folium.Icon(color="blue", icon="briefcase")
    ).add_to(marker_cluster)

display(map_indonesia)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_788af0116b34650b56f7e15c4b79fcec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_788af0116b34650b56f7e15c4b79fcec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_788af0116b34650b56f7e15c4b79fcec = L.map(
#                 &quot;map_788af0116b34650b56f7e15c4b79fcec&quot;,
#                 {
#                     center: [-0.789275, 113.921327],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba21be80ba9528521740d8cc4de438c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba21be80ba9528521740d8cc4de438c1.addTo(map_788af0116b34650b56f7e15c4b79fcec);
#
#
#             var marker_cluster_c648c21a7394abead5ca1c4222e47eca = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_e236a9219229fdfdcf9e0c488177f18c = L.marker(
#                 [-0.878596, 117.343188],
#                 {
# }
#             ).addTo(marker_cluster_c648c21a7394abead5ca1c4222e47eca);
#
#
#             var icon_8f3772c1efd1ef6a4cf74a0f0d5a76ff = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;briefcase&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4b1e32778750cc0c56f33957b8175613 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_4e15e2ff5f086c7601647f3ec3b8349f = $(`&lt;div id=&quot;html_4e15e2ff5f086c7601647f3ec3b8349f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Python Machine Learning&lt;/b&gt;&lt;br&gt;         Kota: Indonesia&lt;br&gt;         Type: Remote&lt;br&gt;         Work Hours: Full-Time&lt;br&gt;         &lt;a href=&quot;https://www.linkedin.com/jobs/search/?currentJobId=4014358169&amp;distance=25&amp;geoId=102478259&amp;keywords=Data%20Scientist&amp;origin=JOB_SEARCH_PAGE_KEYWORD_HISTORY&amp;refresh=true&quot; target=&quot;_blank&quot;&gt;Link Lowongan&lt;/a&gt;     &lt;/div&gt;`)[0];
#                 popup_4b1e32778750cc0c56f33957b8175613.setContent(html_4e15e2ff5f086c7601647f3ec3b8349f);
#
#
#
#         marker_e236a9219229fdfdcf9e0c488177f18c.bindPopup(popup_4b1e32778750cc0c56f33957b8175613)
#         ;
#
#
#
#
#             marker_e236a9219229fdfdcf9e0c488177f18c.bindTooltip(
#                 `&lt;div&gt;
#                      Lowongan di Indonesia
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e236a9219229fdfdcf9e0c488177f18c.setIcon(icon_8f3772c1efd1ef6a4cf74a0f0d5a76ff);
#
#
#             var marker_4c1fe1514de28f9d5ae31f89873ef83f = L.marker(
#                 [-0.878596, 117.343188],
#                 {
# }
#             ).addTo(marker_cluster_c648c21a7394abead5ca1c4222e47eca);
#
#
#             var icon_2a04a837d4cdc0a6672b8fbaffa0ab26 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;briefcase&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_423233f4f84068664657e373eac2fe7c = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_8d7fe9ab371ad73c8ca3be74d50ac2b7 = $(`&lt;div id=&quot;html_8d7fe9ab371ad73c8ca3be74d50ac2b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Python Machine Learning&lt;/b&gt;&lt;br&gt;         Kota: Indonesia&lt;br&gt;         Type: Remote&lt;br&gt;         Work Hours: Full-Time&lt;br&gt;         &lt;a href=&quot;https://www.linkedin.com/jobs/search/?currentJobId=4014358169&amp;distance=25&amp;geoId=102478259&amp;keywords=Data%20Scientist&amp;origin=JOB_SEARCH_PAGE_KEYWORD_HISTORY&amp;refresh=true&quot; target=&quot;_blank&quot;&gt;Link Lowongan&lt;/a&gt;     &lt;/div&gt;`)[0];
#                 popup_423233f4f84068664657e373eac2fe7c.setContent(html_8d7fe9ab371ad73c8ca3be74d50ac2b7);
#
#
#
#         marker_4c1fe1514de28f9d5ae31f89873ef83f.bindPopup(popup_423233f4f84068664657e373eac2fe7c)
#         ;
